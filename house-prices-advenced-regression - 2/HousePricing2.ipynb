# %% [markdown]
# # Data Loading

# %%
import pandas as pd
test = pd.read_csv('test.csv')
test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train = pd.read_csv('train.csv')
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Data Cleaning

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# ANALISIS STATISTIK DESKRIPTIF

train.describe(include="all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
# CEK MISSING VALUES
missing_values = train.isnull().sum()
missing_values[missing_values > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ## Missing Value Handling
#
# - Data hilang besar
# - Split dua kategori (hilang > 1000 dan hilang < 1000)
# - Bedakan penanganan berdasarkan kategori

# %%
less = missing_values[missing_values < 1000 ].index           # dalam pandas => index dan series
over = missing_values[missing_values >= 1000].index

# %%
# cek dengan out
print("data loss dengan miss value < 75%: ")
print(less)

print("\ndata over dengan miss value > 75%: ")
print(over)
# Out:
# data loss dengan miss value < 75%:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
# HANDLING NUMERIC FITUR DATA < 74%
numeric_features = train[less].select_dtypes(include=['number']).columns
train[numeric_features] = train[numeric_features].fillna(train[numeric_features].median())       # isi dengan median

# %%
# HANDLING KATEGORIK FITUR DATA > 75%
categorical_features = train[less].select_dtypes(include=['object']).columns
for column in categorical_features:
    train[column] = train[column].fillna(train[column].mode()[0])             # menggunakan looping karena mode mengembalikan ke series
    # mode()[0] -> jika modus lebih dari satu, maka ambil yang pertama

# %%
missing_values = train.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Alley          1369
# PoolQC         1453
# Fence          1179
# MiscFeature    1406
# dtype: int64

# %%
train[['Alley', 'PoolQC', 'Fence', 'MiscFeature']]
# Out:
#      Alley PoolQC  Fence MiscFeature
# 0      NaN    NaN    NaN         NaN
# 1      NaN    NaN    NaN         NaN
# 2      NaN    NaN    NaN         NaN
# 3      NaN    NaN    NaN         NaN
# 4      NaN    NaN    NaN         NaN
# ...    ...    ...    ...         ...
# 1455   NaN    NaN    NaN         NaN
# 1456   NaN    NaN  MnPrv         NaN
# 1457   NaN    NaN  GdPrv        Shed
# 1458   NaN    NaN    NaN         NaN
# 1459   NaN    NaN    NaN         NaN
#
# [1460 rows x 4 columns]

# %%
# HANDLING OVER => MISSING VALUES > 75% (Just little column so we can drop this)
# sekarang kita ubah train ke df
train = train.drop(columns=['Alley', 'PoolQC', 'Fence', 'MiscFeature'])

# %%
# cek missing values
missing_values = train.isnull().sum()
print(missing_values[missing_values > 0])   # jumlah missing value 0
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Outliers Handling
# - menggunana plt dan sns untuk visualisasikan outliers
# - konsep IQR untuk bersihkan outlier

# %%
# IMPORT LIBRARY UNTUK VISUALISASI
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

for feature in numeric_features:        # untuk setiap fiture dalam kategori fitur numerik
    plt.figure(figsize=(12, 8))         # buat canvas dengan lebar 12 tinggi 8
    sns.boxplot(x=train[feature])          # buat boxplot dengan nilai x dari fitur yang ada (akan ada 76 boxplot)
    plt.title(f"Boxplot of {feature}")  # berikan judul pada boxplot
    plt.show()                          # tunjukkan grafik

# %% [markdown]
# Ada dua pilihan untuk menangani: <br>
# 1. Hapus outlier
# 2. Mengganti dengan nilai moderat atau transformasi
#
# Kali ini kita pakai hapus. Dengan metode IQR

# %%
# Identifikasi outliers dg IQR Metode
Q1 = train[numeric_features].quantile(0.25)
Q3 = train[numeric_features].quantile(0.75)
IQR = Q3 - Q1

# %%
# Filter outlier dengan Mengamankan data di dalam IQR
condition = ~((train[numeric_features] < (Q1 - 1.5 * IQR)) | (train[numeric_features] > (Q3 + 1.5 * IQR))).any(axis=1)
train_filtered_numeric = train.loc[condition, numeric_features] # loc data yng sudh dikategorikan, data dari fitur numerik

# Menggabungkan kembali kolom numerik dengan kolom kategorikal
categorical_features = train.select_dtypes(include=['object']).columns
df = pd.concat([train_filtered_numeric, train.loc[condition, categorical_features]], axis=1)

# %%
# df.shape
print(df[numeric_features].head())
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    1          60         65.0     8450            7            5       2003
# 2    3          60         68.0    11250            7            5       2001
# 4    5          60         84.0    14260            8            5       2000
# 6    7          20         75.0    10084            8            5       2004
# 10  11          20         70.0    11200            5            5       1965
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0           2003       196.0         706  ...           0           61
# 2           2002       162.0         486  ...           0           42
# 4           2000       350.0         655  ...         192           84
# 6           2005       186.0        1369  ...         255           57
# 10          1965         0.0         906  ...           0            0
#
# ...

# %%
# Kita cek lagi boxplotnya
for feature in numeric_features:
    plt.figure(figsize=(12, 8))
    sns.boxplot(x=df[feature])
    plt.title(f"Boxplot of {feature}")
    plt.show()

# %% [markdown]
# ## Normalisasi dan Standarisai
#
# - Normalisasi -> untuk data tidak terdistribusi normal, model berbasis jarak, banyak outliers
# - Standarisasi -> untuk data berdistribusi normal, model bukan jarak, model tree, model regresi, tidak banyak outliers
#
# <br>
# Kunci:<br>
# CHECK APAKAH DATA BERDISTRIBURI NORMAL/TIDAK DENGAN HISTOGRAM/SKEW()

# %%
numeric_features = df.select_dtypes(include=['number']).columns
print(len(numeric_features))
# Out:
# 38

# %%
numeric_features = df.select_dtypes(include=['number']).columns
col = numeric_features

plt.figure(figsize=(20, 25))

for i, col in enumerate(numeric_features, 1):
    plt.subplot(10, 4, i)
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Banyak data yang tidak terdistribusi normal sehingga sebenarnya membutuhkan Normalisasi. Namun, mengingat kasus yang akan dipecahkan adalah regresi maka kita gunakan standarisasi

# %%
# Melihat perbandingan data sebelum dan sesudah standarisasi:

''' SEBELUM '''
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df[numeric_features[3]], kde=True)
plt.title("Histogram sebelum standarisasi")
# Out:
# Text(0.5, 1.0, 'Histogram sebelum standarisasi')

# %%
''' STANDARISASI '''
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
''' SESUDAH'''
plt.subplot(1, 2, 2)
sns.histplot(df[numeric_features[3]], kde=True)
plt.title("Histogram Setelah Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Setelah Standardisasi')

# %% [markdown]
# ## Duplikasi Data

# %%
# IDENTIFIKASI BARIS DUPLIKAT

duplicates = df.duplicated()

print("Baris duplikasi: ")
print(df[duplicates])
# Out:
# Baris duplikasi:
# Empty DataFrame
# Columns: [Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SalePrice, MSZoning, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Heating, HeatingQC, CentralAir, Electrical, KitchenQual, Functional, FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond, PavedDrive, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 77 columns]

# %%
''' TIDAK ADA DUPLIKASI BARIS DATA
Namun, jika ingin mengetahui cara menangani duplikasi data: '''

''' df = df.drop_duplicates() '''

# %% [markdown]
# ## Mengonversi Tipe Data
#
# - One Hot Encoding (1 atau 0)
# - Label Encoding (label num setiap kategori -> ordinal tipe data)
# - Ordinal Encoding -> konversi kategori yang punya urutan ke nilai numerik
#
# SEBELUM ITU KITA PERHATIKAN DULU DATA KATEGORIKAL YANG ADA DI DATASET

# %%
category_features = df.select_dtypes(include=['object']).columns
df[category_features].head(5)
# Out:
#    MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4        RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 6        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 10       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#    Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0       CollgCr       Norm       Norm  ...          Gd        Typ          Gd
# 2       CollgCr       Norm       Norm  ...          Gd        Typ          TA
# 4       NoRidge       Norm       Norm  ...          Gd        Typ          TA
# 6       Somerst       Norm       Norm  ...          Gd        Typ          Gd
# 10       Sawyer       Norm       Norm  ...          TA        Typ          Gd
#
#    GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %% [markdown]
# KITA AKAN GUNAKAN ONE-HOT ENCODING dan LABEL ENCODING karena tidak ada data ordinal di dataset

# %%
'''' ONE HOT ENCODING '''
df_one_hot = pd.get_dummies(df, columns=category_features)
df_one_hot
# Out:
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0    -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2    -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4    -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6    -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10   -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
# ...        ...         ...          ...       ...          ...          ...
# 1448  1.687057    0.038330     0.114843  0.934953    -1.801628     2.308244
# 1451  1.694217   -0.917637     0.722611  0.014215     1.419903    -0.523677
# 1453  1.698991   -0.917637     1.634263  2.938156    -0.996245    -0.523677
# 1454  1.701378   -0.917637    -0.492925 -0.633426     0.614520    -0.523677
# 1455  1.703764    0.356986    -0.492925 -0.480154    -0.190863    -0.523677
#
# ...

# %%
''' LABEL ENCODING '''
from sklearn.preprocessing import LabelEncoder

#Inisialisasi LabelEncoder
label_encoder = LabelEncoder()
df_lencoder = pd.DataFrame(df)

for col in category_features:
    df_lencoder[col] = label_encoder.fit_transform(df[col])

# tampilkan hasil
df_lencoder
# Out:
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0    -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2    -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4    -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6    -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10   -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
# ...        ...         ...          ...       ...          ...          ...
# 1448  1.687057    0.038330     0.114843  0.934953    -1.801628     2.308244
# 1451  1.694217   -0.917637     0.722611  0.014215     1.419903    -0.523677
# 1453  1.698991   -0.917637     1.634263  2.938156    -0.996245    -0.523677
# 1454  1.701378   -0.917637    -0.492925 -0.633426     0.614520    -0.523677
# 1455  1.703764    0.356986    -0.492925 -0.480154    -0.190863    -0.523677
#
# ...

# %% [markdown]
# # EDA & ExDA
#
# - EDA untuk mencari insight, for data scientist and analys, kebutuhan pembangunan model
# - ExDA untuk menyampaikan pesan ke stakeholder, visualisasi yang mudah dicerna, kebutuhan presentasi

# %%
df_lencoder.head()
# Out:
#           Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0  -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2  -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4  -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6  -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10 -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
#
#     YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 0    0.784193      0.704506    1.183911    0.639427  ...            2
# 2    0.704296      0.653431    0.856804    0.101006  ...            2
# 4    0.664347      0.551281    2.665515    0.514611  ...            2
# 6    0.824141      0.806656    1.087703    2.262035  ...            2
# 10  -0.733845     -1.236347   -0.701766    1.128902  ...            3
#
#     Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  GarageCond  \
# ...

# %%
df_lencoder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 557 entries, 0 to 1455
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             557 non-null    float64
#  1   MSSubClass     557 non-null    float64
#  2   LotFrontage    557 non-null    float64
#  3   LotArea        557 non-null    float64
#  4   OverallQual    557 non-null    float64
#  5   OverallCond    557 non-null    float64
#  6   YearBuilt      557 non-null    float64
#  7   YearRemodAdd   557 non-null    float64
#  8   MasVnrArea     557 non-null    float64
#  9   BsmtFinSF1     557 non-null    float64
#  10  BsmtFinSF2     557 non-null    float64
#  11  BsmtUnfSF      557 non-null    float64
#  12  TotalBsmtSF    557 non-null    float64
#  13  1stFlrSF       557 non-null    float64
#  14  2ndFlrSF       557 non-null    float64
#  15  LowQualFinSF   557 non-null    float64
#  16  GrLivArea      557 non-null    float64
# ...

# %%
''' PERIKSA KEMBALI DATA, APAKAH ADA MISSING VALUE? '''

missing_values = df_lencoder.isnull().sum()
missing_percentage = (missing_values / len(df_lencoder)) * 100

missing_data = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
}).sort_values(by='Missing Values', ascending=False)

missing_data[missing_data['Missing Values'] > 0]
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
df_lencoder.describe()
# Out:
#                  Id    MSSubClass   LotFrontage       LotArea   OverallQual  \
# count  5.570000e+02  5.570000e+02  5.570000e+02  5.570000e+02  5.570000e+02
# mean   5.102641e-17  7.175589e-17 -5.102641e-16  3.236988e-16  2.328080e-16
# std    1.000899e+00  1.000899e+00  1.000899e+00  1.000899e+00  1.000899e+00
# min   -1.768952e+00 -9.176372e-01 -2.772055e+00 -2.328982e+00 -3.412393e+00
# 25%   -8.452812e-01 -9.176372e-01 -5.688959e-01 -5.415363e-01 -9.962454e-01
# 50%    4.736214e-02  3.833023e-02  3.887205e-02 -6.848630e-02 -1.908627e-01
# 75%    8.612428e-01  3.569860e-01  4.946980e-01  5.795224e-01  6.145200e-01
# max    1.703764e+00  2.268921e+00  2.925770e+00  3.078932e+00  3.030668e+00
#
#         OverallCond     YearBuilt  YearRemodAdd    MasVnrArea    BsmtFinSF1  \
# count  5.570000e+02  5.570000e+02  5.570000e+02  5.570000e+02  5.570000e+02
# mean   1.052420e-16 -2.407809e-16  8.873811e-16  7.653961e-17 -3.189151e-18
# ...

# %%
df_lencoder.shape
# Out:
# (557, 77)

# %%
''' GUNAKAN HISTOGRAM UNTUK MELIHAT SEBARAN DATA '''

# Hitung jumlah variable (Berapa jumlah kolom di dataset)
num_vars = df_lencoder.shape[1]

# Menentukan jumlah baris dan kolom untuk grid subplot
n_cols = 4
n_rows = -(-num_vars // n_cols) # tanda // adalah pembulatan ke atas

# Buat Subplot
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))

# Flatten axes array untuk memudahkan iterasi jika diperlukan
axes = axes.flatten()

# plot setiap variabel
for i, column in enumerate(df_lencoder.columns):
    df_lencoder[column].hist(ax=axes[i], bins=20, edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Hapus subplot yang tidak terpakai
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Menyesuaikan layout agar ebih rapi
plt.tight_layout()
plt.show()

# %%
'''Visualisasikan beberapa kolom '''

columns_to_plot = ["Utilities", 'YearBuilt', 'LotArea', 'SaleType', "SalePrice", "GrLivArea"]

plt.figure(figsize=(15, 10))
for i, column in enumerate(columns_to_plot,1):
    plt.subplot(2,3,i)
    sns.histplot(df_lencoder[column], kde=True, bins=30)
    plt.title("Distribution of " + column)

plt.tight_layout()
plt.show()

# %%
# MATRIK KORELASI
plt.figure(figsize=(12, 10))
correlation_matrix = df_lencoder.corr()

sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", vmin=1, vmax=1)

plt.title("Correlation Matrix")
plt.show()

# %%
# Menghitung korelasi antara variabel target dan semua variabel lainnya
target_corr = df_lencoder.corr()['SalePrice']

# (Opsional) Mengurutkan hasil korelasi berdasarkan korelasi
target_corr_sorted = target_corr.abs().sort_values(ascending=False)

plt.figure(figsize=(20, 6))
target_corr_sorted.plot(kind='bar')
plt.title(f'Correlation with SalePrice')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %% [markdown]
# Hubungan antara Luas Ruang Tinggal dan Harga Jual<br>
# Analisis di atas menunjukkan hubungan positif yang kuat antara luas ruang tinggal (GrLivArea) dan harga jual (SalePrice). Properti dengan luas ruang tinggal yang lebih besar cenderung memiliki harga jual yang lebih tinggi.<br>
#
# Dampak Luas Garasi<br>
# Korelasi yang moderat antara luas garasi (GarageArea) dan harga jual menunjukkan bahwa properti dengan garasi yang lebih luas memungkinkan untuk dijual dengan harga lebih tinggi.<br>
#
# Outliers dan Distribusi<br>
# Outliers yang ditemukan dalam variabel seperti SalePrice dan GrLivArea dapat memberikan wawasan tentang properti-properti yang luar biasa dalam hal harga dan ukuran. Namun, mereka juga bisa menyesatkan analisis jika tidak ditangani dengan benar. Transformasi logaritmik membantu untuk mengatasi hal ini.<br>
#
# Pengaruh Signifikan dari Ukuran Properti<br>
# Pengembang properti atau investor harus mempertimbangkan ukuran ruang tinggal dan garasi sebagai faktor utama yang memengaruhi nilai jual.<br>
#
# Pengelolaan Outliers<br>
# Outliers yang ditemukan harus dianalisis lebih lanjut untuk memahami apakah mereka mencerminkan kondisi pasar yang unik atau kesalahan dalam data.<br>

# %% [markdown]
# # Data Splitting

# %%
# pisahkan fitur dan target (Y)

X = df_lencoder.drop(columns=['SalePrice'])
y = df_lencoder['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# bagi dataset ke train dan test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# menghitung panjang/jumlah data
print("Jumlah data: ",len(X))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data latih: ",len(x_train))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data test: ",len(x_test))
# Out:
# Jumlah data:  557
# Jumlah data latih:  445
# Jumlah data test:  112

# %% [markdown]
# # Data Modelling

# %%
# Melatih model 1 dengan algoritma LeasT Angle Regression

from sklearn import linear_model
lars = linear_model.Lars(n_nonzero_coefs=1).fit(x_train, y_train)

# Melatih model 2 dengan algoritma Linear Regression
from sklearn.linear_model import LinearRegression
LR = LinearRegression().fit(x_train, y_train)

# Melatih model 3 dengan algoritma Gradient Boost Regressor
from sklearn.ensemble import GradientBoostingRegressor
GBR = GradientBoostingRegressor(random_state=184)
GBR.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=184)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluasi pada model LARS
pred_lars = lars.predict(x_test)
mae_lars = mean_absolute_error(y_test, pred_lars)
mse_lars = mean_squared_error(y_test, pred_lars)
r2_lars = r2_score(y_test, pred_lars)

# Membuat dictionary untuk menyimpan hasil evaluasi
data = {
    'MAE': [mae_lars],
    'MSE': [mse_lars],
    'R2': [r2_lars]
}

# Konversi dictionary menjadi DataFrame
df_results = pd.DataFrame(data, index=['Lars'])
df_results
# Out:
#            MAE       MSE        R2
# Lars  0.720054  0.817625 -0.018517

# %%
# Evaluasi pada model Linear Regression
pred_LR = LR.predict(x_test)
mae_LR = mean_absolute_error(y_test, pred_LR)
mse_LR = mean_squared_error(y_test, pred_LR)
r2_LR = r2_score(y_test, pred_LR)

# Menambahkan hasil evaluasi LR ke DataFrame
df_results.loc['Linear Regression'] = [mae_LR, mse_LR, r2_LR]
df_results
# Out:
#                         MAE       MSE        R2
# Lars               0.720054  0.817625 -0.018517
# Linear Regression  0.237442  0.095830  0.880624

# %%
# Evaluasi pada model Gradient Boosting
pred_GBR = GBR.predict(x_test)
mae_GBR = mean_absolute_error(y_test, pred_GBR)
mse_GBR = mean_squared_error(y_test, pred_GBR)
r2_GBR = r2_score(y_test, pred_GBR)

# Menambahkan hasil evaluasi GBR ke DataFrame
df_results.loc['GradientBoostingRegressor'] = [mae_GBR, mse_GBR, r2_GBR]
df_results
# Out:
#                                 MAE       MSE        R2
# Lars                       0.720054  0.817625 -0.018517
# Linear Regression          0.237442  0.095830  0.880624
# GradientBoostingRegressor  0.217360  0.089055  0.889065

# %% [markdown]
# Dari hasil model evaluation. Gradient Boosting memiliki nilai error yang paling kecil dengan evaluasi R2 mendekati 1 terbesar. Sehingga GradientBoosting adalah model yang dipilih

# %% [markdown]
# # Save Model

# %%
import joblib

# Menyimpan model ke dalam file
joblib.dump(GBR, 'gbr_model.joblib')
# Out:
# ['gbr_model.joblib']

# %%
import pickle

# Menyimpan model ke dalam file
with open('gbr_model.pkl', 'wb') as file:
    pickle.dump(GBR, file)
